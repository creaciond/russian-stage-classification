# %% [markdown]
# # Getting initial data

# %% [markdown]
# ## 1 &emsp; API Interaction

# %%
import os

from dracor_api import get_play_names, play_metadata_api, download_directions
from file_work import save_directions

# %% [markdown]
# We first use DraCor API (see [here](https://dracor.org/documentation/api/)); the methods for addressing it are in `dracor_api.py`.
#
# If you run this notebook for the first time, run the following cell to create all necessary folders:

# %%
directions_folder = ".." + os.sep + "api_data" + os.sep + "directions"
datasets_folder = ".." + os.sep + "api_data" + os.sep + "csv"

if not os.path.exists(directions_folder):
    os.mkdir(directions_folder)
if not os.path.exists(datasets_folder):
    os.mkdir(datasets_folder)

# %% [markdown]
# Directions extracted from the corpus will be stored in `directions_raw` subfolder.

# %%
directions_raw_folder = ".." + os.sep + "api_data" + os.sep + "directions" + os.sep + "raw"
if not os.path.exists(directions_raw_folder):
    os.mkdir(directions_raw_folder)

# %%
play_names = get_play_names()

all_data = {
    "play_id": [],
    "title": [],
    "author": [],
    "characters": [],
    "segments": [],
}

for play_id in play_names:
    directions = download_directions(play_id)
    data = play_metadata_api(play_id)
    print(data)
    if data:
        for key, value in data.items():
            all_data["play_id"].append(play_id)
            all_data[key].append(value)
    if directions:
        save_directions(directions_raw_folder, play_id, directions)
# Out:
# {'title': 'Не убий', 'author': 'Андреев, Леонид Николаевич', 'characters': 23, 'segments': 6}
# {'title': 'Мысль', 'author': 'Андреев, Леонид Николаевич', 'characters': 15, 'segments': 5}
# {'title': 'Закат', 'author': 'Бабель, Исаак Эммануилович', 'characters': 36, 'segments': 8}
# {'title': 'Мария', 'author': 'Бабель, Исаак Эммануилович', 'characters': 22, 'segments': 8}
# {'title': 'Король на площади', 'author': 'Блок, Александр Александрович', 'characters': 29, 'segments': 21}
# {'title': 'Незнакомка', 'author': 'Блок, Александр Александрович', 'characters': 34, 'segments': 3}
# {'title': 'Балаганчик', 'author': 'Блок, Александр Александрович', 'characters': 16, 'segments': 2}
# {'title': 'Последние дни (Пушкин)', 'author': 'Булгаков, Михаил Афанасьевич', 'characters': 36, 'segments': 10}
# {'title': 'Иван Васильевич', 'author': 'Булгаков, Михаил Афанасьевич', 'characters': 16, 'segments': 3}
# {'title': 'Кабала святош (Мольер)', 'author': 'Булгаков, Михаил Афанасьевич', 'characters': 24, 'segments': 4}
# {'title': 'Дни Турбиных', 'author': 'Булгаков, Михаил Афанасьевич', 'characters': 29, 'segments': 5}
# {'title': 'Бег', 'author': 'Булгаков, Михаил Афанасьевич', 'characters': 40, 'segments': 7}
# {'title': 'Полоумный Журден', 'author': 'Булгаков, Михаил Афанасьевич', 'characters': 22, 'segments': 3}
# {'title': 'Вельзен, или освобожденная Голландия', 'author': 'Глинка, Фёдор Николаевич', 'characters': 22, 'segments': 40}
# {'title': 'Лакейская', 'author': 'Гоголь, Николай Васильевич', 'characters': 9, 'segments': 8}
# {'title': 'Игроки', 'author': 'Гоголь, Николай Васильевич', 'characters': 9, 'segments': 20}
# {'title': 'Ревизор', 'author': 'Гоголь, Николай Васильевич', 'characters': 31, 'segments': 52}
# {'title': 'Театральный разъезд после представления новой комедии', 'author': 'Гоголь, Николай Васильевич', 'characters': 99, 'segments': 36}
# {'title': 'Тяжба', 'author': 'Гоголь, Николай Васильевич', 'characters': 3, 'segments': 3}
# {'title': 'Отрывок', 'author': 'Гоголь, Николай Васильевич', 'characters': 4, 'segments': 2}
# {'title': 'Женитьба', 'author': 'Гоголь, Николай Васильевич', 'characters': 12, 'segments': 42}
# {'title': 'Утро делового человека', 'author': 'Гоголь, Николай Васильевич', 'characters': 5, 'segments': 5}
# {'title': 'На дне', 'author': 'Горький, Максим', 'characters': 17, 'segments': 2}
# {'title': 'Егор Булычов и другие', 'author': 'Горький, Максим', 'characters': 22, 'segments': 71}
# {'title': 'Горе от ума', 'author': 'Грибоедов, Александр Сергеевич', 'characters': 31, 'segments': 49}
# {'title': 'Гондла', 'author': 'Гумилёв, Николай Степанович', 'characters': 8, 'segments': 16}
# {'title': 'Актеон', 'author': 'Гумилёв, Николай Степанович', 'characters': 15, 'segments': 7}
# {'title': 'Дон-Жуан в Египте', 'author': 'Гумилёв, Николай Степанович', 'characters': 4, 'segments': 2}
# {'title': 'Дитя Аллаха', 'author': 'Гумилёв, Николай Степанович', 'characters': 20, 'segments': 3}
# {'title': 'Тоисиоков', 'author': 'Дашкова, Екатерина Романовна', 'characters': 11, 'segments': 40}
# {'title': 'Ябеда', 'author': 'Капнист, Василий Васильевич', 'characters': 15, 'segments': 16}
# {'title': 'Антигона', 'author': 'Капнист, Василий Васильевич', 'characters': 7, 'segments': 8}
# {'title': 'Рембрандт', 'author': 'Кедрин, Дмитрий Борисович', 'characters': 41, 'segments': 37}
# {'title': 'Ольга', 'author': 'Княжнин, Яков Борисович', 'characters': 7, 'segments': 12}
# {'title': 'Дидона', 'author': 'Княжнин, Яков Борисович', 'characters': 9, 'segments': 13}
# {'title': 'Хвастун', 'author': 'Княжнин, Яков Борисович', 'characters': 11, 'segments': 50}
# {'title': 'Вадим Новгородский', 'author': 'Княжнин, Яков Борисович', 'characters': 7, 'segments': 12}
# {'title': 'Чудаки', 'author': 'Княжнин, Яков Борисович', 'characters': 14, 'segments': 21}
# {'title': 'Фомушка – бабушкин внучек', 'author': 'Кропотов, Пётр Андреевич', 'characters': 10, 'segments': 33}
# {'title': 'Модная лавка', 'author': 'Крылов, Иван Андреевич', 'characters': 11, 'segments': 39}
# {'title': 'Филомела', 'author': 'Крылов, Иван Андреевич', 'characters': 7, 'segments': 25}
# {'title': 'Сонный порошок или похищенная крестьянка', 'author': 'Крылов, Иван Андреевич', 'characters': 10, 'segments': 6}
# {'title': 'Пирог', 'author': 'Крылов, Иван Андреевич', 'characters': 9, 'segments': 14}
# {'title': 'Урок дочкам', 'author': 'Крылов, Иван Андреевич', 'characters': 9, 'segments': 10}
# {'title': 'Проказники', 'author': 'Крылов, Иван Андреевич', 'characters': 10, 'segments': 16}
# {'title': 'Подщипа или Трумф', 'author': 'Крылов, Иван Андреевич', 'characters': 8, 'segments': 11}
# {'title': 'Американцы', 'author': 'Крылов, Иван Андреевич', 'characters': 10, 'segments': 23}
# {'title': 'Окопировался', 'author': 'Лажечников, Иван Иванович', 'characters': 22, 'segments': 26}
# {'title': 'Хороша и дурна, и глупа и умна', 'author': 'Ленский, Дмитрий Тимофеевич', 'characters': 6, 'segments': 7}
# {'title': 'Странный человек', 'author': 'Лермонтов, Михаил Юрьевич', 'characters': 48, 'segments': 13}
# {'title': 'Маскарад', 'author': 'Лермонтов, Михаил Юрьевич', 'characters': 48, 'segments': 46}
# {'title': 'Тамира и Селим', 'author': 'Ломоносов, Михаил Васильевич', 'characters': 10, 'segments': 29}
# {'title': 'Демофонт', 'author': 'Ломоносов, Михаил Васильевич', 'characters': 8, 'segments': 29}
# {'title': 'Агриопа', 'author': 'Майков, Василий Иванович', 'characters': 8, 'segments': 28}
# {'title': 'Фемист и Иеронима', 'author': 'Майков, Василий Иванович', 'characters': 6, 'segments': 25}
# {'title': 'Клоп', 'author': 'Маяковский, Владимир Владимирович', 'characters': 98, 'segments': 9}
# {'title': 'Баня', 'author': 'Маяковский, Владимир Владимирович', 'characters': 24, 'segments': 33}
# {'title': 'Мистерия-буфф', 'author': 'Маяковский, Владимир Владимирович', 'characters': 65, 'segments': 7}
# {'title': 'Дети Ванюшина', 'author': 'Найдёнов, Сергей Александрович', 'characters': 16, 'segments': 4}
# {'title': 'Забракованные', 'author': 'Некрасов, Николай Алексеевич', 'characters': 9, 'segments': 7}
# {'title': 'Самолюбивый стихотворец', 'author': 'Николев, Николай Петрович', 'characters': 8, 'segments': 19}
# {'title': 'Димитрий Донской', 'author': 'Озеров, Владислав Александрович', 'characters': 10, 'segments': 17}
# {'title': 'Бедная невеста', 'author': 'Островский, Александр Николаевич', 'characters': 28, 'segments': 64}
# {'title': 'Бедность не порок', 'author': 'Островский, Александр Николаевич', 'characters': 18, 'segments': 19}
# {'title': 'Гроза', 'author': 'Островский, Александр Николаевич', 'characters': 29, 'segments': 40}
# {'title': 'Волки и овцы', 'author': 'Островский, Александр Николаевич', 'characters': 18, 'segments': 34}
# {'title': 'Снегурочка', 'author': 'Островский, Александр Николаевич', 'characters': 42, 'segments': 28}
# {'title': 'Лес', 'author': 'Островский, Александр Николаевич', 'characters': 12, 'segments': 10}
# {'title': 'Бесприданница', 'author': 'Островский, Александр Николаевич', 'characters': 11, 'segments': 19}
# {'title': 'Свои люди – сочтемся', 'author': 'Островский, Александр Николаевич', 'characters': 8, 'segments': 13}
# {'title': 'На всякого мудреца довольно простоты', 'author': 'Островский, Александр Николаевич', 'characters': 16, 'segments': 24}
# {'title': 'Лукавин', 'author': 'Писарев, Александр Иванович', 'characters': 13, 'segments': 30}
# {'title': 'Горькая судьбина', 'author': 'Писемский, Алексей Феофилактович', 'characters': 23, 'segments': 26}
# {'title': 'Ермак, покоритель Сибири', 'author': 'Плавильщиков, Пётр Алексеевич', 'characters': 11, 'segments': 34}
# {'title': 'Сговор Кутейкина', 'author': 'Плавильщиков, Пётр Алексеевич', 'characters': 9, 'segments': 8}
# {'title': 'Сродство мировых сил', 'author': 'Прутков, Козьма', 'characters': 10, 'segments': 11}
# {'title': 'Опрометчивый Турка, или: Приятно ли быть внуком?', 'author': 'Прутков, Козьма', 'characters': 7, 'segments': 2}
# {'title': 'Черепослов, сиречь Френолог', 'author': 'Прутков, Козьма', 'characters': 9, 'segments': 8}
# {'title': 'Блонды', 'author': 'Прутков, Козьма', 'characters': 3, 'segments': 5}
# {'title': 'Спор древних греческих философов об изящном', 'author': 'Прутков, Козьма', 'characters': 2, 'segments': 1}
# {'title': 'Фантазия', 'author': 'Прутков, Козьма', 'characters': 13, 'segments': 4}
# {'title': 'Борис Годунов', 'author': 'Пушкин, Александр Сергеевич', 'characters': 79, 'segments': 22}
# {'title': 'Русалка', 'author': 'Пушкин, Александр Сергеевич', 'characters': 18, 'segments': 5}
# {'title': 'Моцарт и Сальери', 'author': 'Пушкин, Александр Сергеевич', 'characters': 2, 'segments': 1}
# {'title': 'Каменный гость', 'author': 'Пушкин, Александр Сергеевич', 'characters': 11, 'segments': 10}
# {'title': 'Скупой рыцарь', 'author': 'Пушкин, Александр Сергеевич', 'characters': 5, 'segments': 3}
# {'title': 'Сцены из рыцарских времен', 'author': 'Пушкин, Александр Сергеевич', 'characters': 23, 'segments': 14}
# {'title': 'Пир во время чумы', 'author': 'Пушкин, Александр Сергеевич', 'characters': 7, 'segments': 2}
# {'title': 'Смерть Пазухина', 'author': 'Салтыков-Щедрин, Михаил Евграфович', 'characters': 15, 'segments': 32}
# {'title': 'Димитрий Самозванец', 'author': 'Сумароков, Александр Петрович', 'characters': 6, 'segments': 7}
# {'title': 'Семира', 'author': 'Сумароков, Александр Петрович', 'characters': 10, 'segments': 33}
# {'title': 'Артистона', 'author': 'Сумароков, Александр Петрович', 'characters': 11, 'segments': 24}
# {'title': 'Синав и Трувор', 'author': 'Сумароков, Александр Петрович', 'characters': 6, 'segments': 25}
# {'title': 'Хорев', 'author': 'Сумароков, Александр Петрович', 'characters': 12, 'segments': 27}
# {'title': 'Смерть Тарелкина', 'author': 'Сухово-Кобылин, Александр Васильевич', 'characters': 24, 'segments': 37}
# {'title': 'Свадьба Кречинского', 'author': 'Сухово-Кобылин, Александр Васильевич', 'characters': 11, 'segments': 40}
# {'title': 'Дело', 'author': 'Сухово-Кобылин, Александр Васильевич', 'characters': 20, 'segments': 42}
# {'title': 'Царь Фёдор Иоаннович', 'author': 'Толстой, Алексей Константинович', 'characters': 78, 'segments': 11}
# {'title': 'Смерть Иоанна Грозного', 'author': 'Толстой, Алексей Константинович', 'characters': 70, 'segments': 53}
# {'title': 'Царь Борис', 'author': 'Толстой, Алексей Константинович', 'characters': 102, 'segments': 14}
# {'title': 'Живой труп', 'author': 'Толстой, Лев Николаевич', 'characters': 40, 'segments': 82}
# {'title': "Власть тьмы, или 'коготок увяз, всей птичке пропасть'", 'author': 'Толстой, Лев Николаевич', 'characters': 24, 'segments': 100}
# {'title': 'Противогазы', 'author': 'Третьяков, Сергей Михайлович', 'characters': 48, 'segments': 3}
# {'title': 'Разговор на большой дороге', 'author': 'Тургенев, Иван Сергеевич', 'characters': 3, 'segments': 1}
# {'title': 'Холостяк', 'author': 'Тургенев, Иван Сергеевич', 'characters': 11, 'segments': 3}
# {'title': 'Завтрак у предводителя', 'author': 'Тургенев, Иван Сергеевич', 'characters': 11, 'segments': 11}
# {'title': 'Вечер в Сорренте', 'author': 'Тургенев, Иван Сергеевич', 'characters': 7, 'segments': 13}
# {'title': 'Провинциалка', 'author': 'Тургенев, Иван Сергеевич', 'characters': 7, 'segments': 10}
# {'title': 'Неосторожность', 'author': 'Тургенев, Иван Сергеевич', 'characters': 6, 'segments': 4}
# {'title': 'Нахлебник', 'author': 'Тургенев, Иван Сергеевич', 'characters': 14, 'segments': 1}
# {'title': 'Месяц в деревне', 'author': 'Тургенев, Иван Сергеевич', 'characters': 13, 'segments': 2}
# {'title': 'Где тонко, там и рвётся', 'author': 'Тургенев, Иван Сергеевич', 'characters': 10, 'segments': 12}
# {'title': 'Бригадир', 'author': 'Фонвизин, Денис Иванович', 'characters': 8, 'segments': 4}
# {'title': 'Выбор гувернера', 'author': 'Фонвизин, Денис Иванович', 'characters': 12, 'segments': 13}
# {'title': 'Корион', 'author': 'Фонвизин, Денис Иванович', 'characters': 5, 'segments': 17}
# {'title': 'Недоросль', 'author': 'Фонвизин, Денис Иванович', 'characters': 15, 'segments': 26}
# {'title': 'Венецианская монахиня', 'author': 'Херасков, Михаил Матвеевич', 'characters': 7, 'segments': 17}
# {'title': 'Освобожденная Москва', 'author': 'Херасков, Михаил Матвеевич', 'characters': 22, 'segments': 47}
# {'title': 'Снежимочка', 'author': 'Хлебников, Велимир', 'characters': 67, 'segments': 4}
# {'title': 'Взаимные испытания', 'author': 'Хмельницкий, Николай Иванович', 'characters': 4, 'segments': 4}
# {'title': 'Светский случай', 'author': 'Хмельницкий, Николай Иванович', 'characters': 6, 'segments': 6}
# {'title': 'Воздушные замки', 'author': 'Хмельницкий, Николай Иванович', 'characters': 5, 'segments': 7}
# {'title': 'Говорун', 'author': 'Хмельницкий, Николай Иванович', 'characters': 12, 'segments': 9}
# {'title': 'Три сестры', 'author': 'Чехов, Антон Павлович', 'characters': 14, 'segments': 21}
# {'title': 'Вишневый сад', 'author': 'Чехов, Антон Павлович', 'characters': 14, 'segments': 36}
# {'title': 'Трагик поневоле (Из дачной жизни)', 'author': 'Чехов, Антон Павлович', 'characters': 2, 'segments': 1}
# {'title': 'Татьяна Репина', 'author': 'Чехов, Антон Павлович', 'characters': 28, 'segments': 1}
# {'title': 'Предложение', 'author': 'Чехов, Антон Павлович', 'characters': 3, 'segments': 3}
# {'title': 'Ночь перед судом', 'author': 'Чехов, Антон Павлович', 'characters': 4, 'segments': 5}
# {'title': 'На большой дороге', 'author': 'Чехов, Антон Павлович', 'characters': 11, 'segments': 5}
# {'title': 'Медведь', 'author': 'Чехов, Антон Павлович', 'characters': 3, 'segments': 4}
# {'title': 'Юбилей', 'author': 'Чехов, Антон Павлович', 'characters': 5, 'segments': 7}
# {'title': 'Дядя Ваня', 'author': 'Чехов, Антон Павлович', 'characters': 10, 'segments': 21}
# {'title': 'Чайка', 'author': 'Чехов, Антон Павлович', 'characters': 12, 'segments': 43}
# {'title': 'Леший', 'author': 'Чехов, Антон Павлович', 'characters': 13, 'segments': 37}
# {'title': 'Свадьба', 'author': 'Чехов, Антон Павлович', 'characters': 13, 'segments': 8}
# {'title': 'Иванов', 'author': 'Чехов, Антон Павлович', 'characters': 17, 'segments': 39}
# {'title': 'Не любо – не слушай, а лгать не мешай', 'author': 'Шаховской, Александр Александрович', 'characters': 6, 'segments': 13}
# {'title': 'Урок кокеткам, или липецкие воды', 'author': 'Шаховской, Александр Александрович', 'characters': 11, 'segments': 20}
# {'title': 'Пустодомы', 'author': 'Шаховской, Александр Александрович', 'characters': 12, 'segments': 30}
# {'title': 'Своя семья, или замужняя невеста', 'author': 'Шаховской, Александр Александрович', 'characters': 8, 'segments': 5}

# %% [markdown]
# ## 2 &emsp; Metadata retrieval
#
# Some data is fetched from RusDraCor API, other (e.g. directions/lemma/wordform count, their average) is computed manually.

# %%
from preprocessing import extract_lemmas, extract_pos, prepare_for_classification

# %% [markdown]
# When we address the `metadata` request from DraCor API, it returns a CSV file; we first copy it from Downloads folder to the `datasets_folder`.

# %%
from shutil import copyfile

# %%
# change this to your Downloads folder if you're re-running 
# this on your laptop
# downloads_path = "/Users/dariamaximova/Downloads/metadata.csv"
datasets_path = datasets_folder + os.sep + "metadata.csv"
# copyfile(downloads_path, datasets_path)

# %% [markdown]
# Now we are able to open the `metadata.csv` file as a Pandas dataframe to take a more detailed look at plays and information on them.

# %%
import pandas as pd

# %%
df = pd.read_csv(datasets_path, sep=",", encoding="utf-8")
df.head()
# Out:
#                name    genre  year  numOfSegments  numOfActs  numOfSpeakers  \
# 0     andreyev-mysl  tragedy  1914              6          3             15
# 1  andreyev-ne-ubiy      NaN  1913              6          5             23
# 2      babel-marija      NaN  1935              8          0             22
# 3       babel-zakat      NaN  1927              8          0             36
# 4  blok-balaganchik      NaN  1906              3          0             16
#
#    yearWritten  yearPremiered  yearPrinted  size  averageClustering   density  \
# 0       1913.0         1914.0       1914.0    15           0.810899  0.371429
# 1       1913.0         1913.0       1913.0    23           0.912104  0.588933
# 2          NaN         1964.0       1935.0    22           0.876271  0.320346
# 3          NaN         1927.0       1928.0    36           0.896057  0.396825
# 4       1906.0         1906.0       1906.0    16           0.942857  0.600000
#
#    averagePathLength  averageDegree  diameter  maxDegree  \
# 0           1.914286       5.200000         3          9
# 1           1.415020      12.956522         3         21
# 2           1.909091       6.727273         3         14
# 3           1.666667      13.888889         3         31
# 4           1.400000       9.000000         2         15
#
#               maxDegreeIds  wikipediaLinkCount
# 0              kerzhentsev                   0
# 1  yakov|vasilisa_petrovna                   0
# 2                    katya                   0
# 3                   mendel                   0
# 4             pero|arlekin                   0

# %% [markdown]
# ### 2.1 &emsp; Removing columns from other research
#
# NaN values in `genre` column are replaced with their non-NaN analogue: `unknown`. The column is also converted to `category` type.
#
# We have a `year` column which gets us a single year instead of three different ones — `yearWritten`, `yearPremiered`, `yearPrinted`, so we can drop these.

# %%
df["genre"] = df["genre"].fillna("unknown").astype("category")
year_cols = ["yearWritten", "yearPremiered", "yearPrinted"]
df.drop(year_cols, axis=1, inplace=True)

graph_cols = ["size", "averageClustering", "density", "averagePathLength", 
              "averageDegree", "diameter", "maxDegree", "maxDegreeIds"]
df.drop(graph_cols, axis=1, inplace=True)
df.head()
# Out:
#                name    genre  year  numOfSegments  numOfActs  numOfSpeakers  \
# 0     andreyev-mysl  tragedy  1914              6          3             15
# 1  andreyev-ne-ubiy  unknown  1913              6          5             23
# 2      babel-marija  unknown  1935              8          0             22
# 3       babel-zakat  unknown  1927              8          0             36
# 4  blok-balaganchik  unknown  1906              3          0             16
#
#    wikipediaLinkCount
# 0                   0
# 1                   0
# 2                   0
# 3                   0
# 4                   0

# %% [markdown]
# ### 2.2 &emsp; Adding columns regarding directions
#
# Now we have to add information regarding directions data we indicated earlier:
#
# * directions/lemma/wordform count,
# * lemma/wordform average per play
#
# That's already five new features!

# %%
from file_work import load_directions

# %% [markdown]
# Each type of directions processing (lemmas, POS tags, lemmas + POS) will be saved in a separate folder.

# %%
directions_pos_folder = ".." + os.sep + "api_data" + os.sep + "directions" + os.sep + "pos"
if not os.path.exists(directions_pos_folder):
    os.mkdir(directions_pos_folder)
    
directions_lemmas_folder = ".." + os.sep + "api_data" + os.sep + "directions" + os.sep + "lemmas"
if not os.path.exists(directions_lemmas_folder):
    os.mkdir(directions_lemmas_folder)
    
directions_lemmaspos_folder = ".." + os.sep + "api_data" + os.sep + "directions" + os.sep + "lemmaspos"
if not os.path.exists(directions_lemmaspos_folder):
    os.mkdir(directions_lemmaspos_folder)

# %% [markdown]
# For lemmatisation, we use Mystem, rule-based morphological analyzer developed by Ilya Segalivich and maintained by Yandex. Its Python wrapper is `pymystem3`.

# %%
from nltk.corpus import stopwords
from nltk.tokenize import wordpunct_tokenize
from pymystem3 import Mystem
from statistics import mean

# %%
additional_features = {
    "directionsCount": [],
    "directionsTokens": [],
    "directionsTokensAverage": [],
    "directionsLemmas": [],
    "directionsLemmasAverage": [],
    "directionsPOS": [],
    "directionsPOSAverage": []
}
mystem = Mystem()
stops = stopwords.words("russian")

# %%
total_plays = len(df["name"])
for i, play_id in enumerate(df["name"]):
    directions_raw = load_directions(directions_raw_folder, play_id)
    directions_count = len(directions_raw)
    
    additional_features["directionsCount"].append(len(directions_raw))
    
    tokens_count = wordpunct_tokenize(" ".join(directions_raw))
    additional_features["directionsTokens"].append(len(tokens_count))
    tokens_average = len(tokens_count)/directions_count
    additional_features["directionsTokensAverage"].append(tokens_average)
    
    directions_lemmas = extract_lemmas(directions_raw, mystem)
    lemmas_count = sum([len(line) for line in directions_lemmas])
    additional_features["directionsLemmas"].append(lemmas_count)
    lemmas_mean = mean([len(line) for line in directions_lemmas])
    additional_features["directionsLemmasAverage"].append(lemmas_mean)
    directions_lemmas_str = [" ".join(lemmas) for lemmas in directions_lemmas]
    save_directions(directions_lemmas_folder, play_id, directions_lemmas_str)
    
    directions_pos = extract_pos(directions_raw, mystem)
    pos_count = sum([len(pos_line) for pos_line in directions_pos])
    additional_features["directionsPOS"].append(pos_count)
    pos_mean = mean([len(pos_line) for pos_line in directions_pos])
    additional_features["directionsPOSAverage"].append(pos_mean)
    directions_pos_str = [" ".join(pos) for pos in directions_pos]
    save_directions(directions_pos_folder, play_id, directions_pos_str)
    
    print("Play {}, id: {}, ready: {:.2f}%".format(i+1, play_id, ((i+1)/total_plays)*100))
# Out:
# Play 1, id: andreyev-mysl, ready: 0.71%
# Play 2, id: andreyev-ne-ubiy, ready: 1.42%
# Play 3, id: babel-marija, ready: 2.13%
# Play 4, id: babel-zakat, ready: 2.84%
# Play 5, id: blok-balaganchik, ready: 3.55%
# Play 6, id: blok-korol-na-ploschadi, ready: 4.26%
# Play 7, id: blok-neznakomka, ready: 4.96%
# Play 8, id: bulgakov-beg, ready: 5.67%
# Play 9, id: bulgakov-dni-turbinyh, ready: 6.38%
# Play 10, id: bulgakov-ivan-vasilevich, ready: 7.09%
# Play 11, id: bulgakov-kabala-svjatosh, ready: 7.80%
# Play 12, id: bulgakov-poloumnyj-zhurden, ready: 8.51%
# Play 13, id: bulgakov-poslednie-dni, ready: 9.22%
# Play 14, id: chekhov-chaika, ready: 9.93%
# Play 15, id: chekhov-djadja-vanja, ready: 10.64%
# Play 16, id: chekhov-ivanov, ready: 11.35%
# Play 17, id: chekhov-jubilej, ready: 12.06%
# Play 18, id: chekhov-leshii, ready: 12.77%
# Play 19, id: chekhov-medved, ready: 13.48%
# Play 20, id: chekhov-na-bolshoi-doroge, ready: 14.18%
# Play 21, id: chekhov-noch-pered-sudom, ready: 14.89%
# Play 22, id: chekhov-predlozhenie, ready: 15.60%
# Play 23, id: chekhov-svadba, ready: 16.31%
# Play 24, id: chekhov-tatjana-repina, ready: 17.02%
# Play 25, id: chekhov-tragik-ponevole, ready: 17.73%
# Play 26, id: chekhov-tri-sestry, ready: 18.44%
# Play 27, id: chekhov-vishnevyi-sad, ready: 19.15%
# Play 28, id: dashkova-toisiokov, ready: 19.86%
# Play 29, id: fonvizin-brigadir, ready: 20.57%
# Play 30, id: fonvizin-korion, ready: 21.28%
# Play 31, id: fonvizin-nedorosl, ready: 21.99%
# Play 32, id: fonvizin-vybor-guvernera, ready: 22.70%
# Play 33, id: glinka-velzen, ready: 23.40%
# Play 34, id: gogol-igroki, ready: 24.11%
# Play 35, id: gogol-lakeiskaja, ready: 24.82%
# Play 36, id: gogol-otryvok, ready: 25.53%
# Play 37, id: gogol-revizor, ready: 26.24%
# Play 38, id: gogol-teatralnyi-razezd, ready: 26.95%
# Play 39, id: gogol-tjazhba, ready: 27.66%
# Play 40, id: gogol-utro-delovogo-cheloveka, ready: 28.37%
# Play 41, id: gogol-zhenitba, ready: 29.08%
# Play 42, id: gorky-egor-bulychov-i-drugie, ready: 29.79%
# Play 43, id: gorky-na-dne, ready: 30.50%
# Play 44, id: griboyedov-gore-ot-uma, ready: 31.21%
# Play 45, id: gumilyov-akteon, ready: 31.91%
# Play 46, id: gumilyov-ditja-allaha, ready: 32.62%
# Play 47, id: gumilyov-don-zhuan-v-egipte, ready: 33.33%
# Play 48, id: gumilyov-gondla, ready: 34.04%
# Play 49, id: kapnist-antigona, ready: 34.75%
# Play 50, id: kapnist-yabeda, ready: 35.46%
# Play 51, id: kedrin-rembrandt, ready: 36.17%
# Play 52, id: kheraskov-osvobozhdennaja-moskva, ready: 36.88%
# Play 53, id: kheraskov-venecianskaya-monahinya, ready: 37.59%
# Play 54, id: khlebnikov-snezhimochka, ready: 38.30%
# Play 55, id: khmelnitsky-govorun, ready: 39.01%
# Play 56, id: khmelnitsky-svetskiy-sluchay, ready: 39.72%
# Play 57, id: khmelnitsky-vozdushnye-zamki, ready: 40.43%
# Play 58, id: khmelnitsky-vzaimnye-ispytaniya, ready: 41.13%
# Play 59, id: knyazhnin-chudaki, ready: 41.84%
# Play 60, id: knyazhnin-didona, ready: 42.55%
# Play 61, id: knyazhnin-hvastun, ready: 43.26%
# Play 62, id: knyazhnin-olga, ready: 43.97%
# Play 63, id: knyazhnin-vadim-novgorodskij, ready: 44.68%
# Play 64, id: kropotov-fomushka, ready: 45.39%
# Play 65, id: krylov-amerikantsy, ready: 46.10%
# Play 66, id: krylov-filomela, ready: 46.81%
# Play 67, id: krylov-modnaja-lavka, ready: 47.52%
# Play 68, id: krylov-pirog, ready: 48.23%
# Play 69, id: krylov-podschipa-ili-trumf, ready: 48.94%
# Play 70, id: krylov-prokazniki, ready: 49.65%
# Play 71, id: krylov-sonnyj-poroshok, ready: 50.35%
# Play 72, id: krylov-urok-dochkam, ready: 51.06%
# Play 73, id: lazhechnikov-okopirovalsya, ready: 51.77%
# Play 74, id: lensky-horosha-i-durna, ready: 52.48%
# Play 75, id: lermontov-maskarad, ready: 53.19%
# Play 76, id: lermontov-strannyj-chelovek, ready: 53.90%
# Play 77, id: lomonosov-demofont, ready: 54.61%
# Play 78, id: lomonosov-tamira-i-selim, ready: 55.32%
# Play 79, id: majkov-agriopa, ready: 56.03%
# Play 80, id: majkov-femist-i-ieronima, ready: 56.74%
# Play 81, id: mayakovsky-banja, ready: 57.45%
# Play 82, id: mayakovsky-klop, ready: 58.16%
# Play 83, id: mayakovsky-misteriya-buff, ready: 58.87%
# Play 84, id: naydyonov-deti-vanjushina, ready: 59.57%
# Play 85, id: nekrasov-zabrakovannye, ready: 60.28%
# Play 86, id: nikolev-samolyubivyj-stihotvorec, ready: 60.99%
# Play 87, id: ostrovsky-bednaja-nevesta, ready: 61.70%
# Play 88, id: ostrovsky-bednost-ne-porok, ready: 62.41%
# Play 89, id: ostrovsky-bespridannitsa, ready: 63.12%
# Play 90, id: ostrovsky-groza, ready: 63.83%
# Play 91, id: ostrovsky-les, ready: 64.54%
# Play 92, id: ostrovsky-na-vsyakogo-mudreca-dovolno-prostoty, ready: 65.25%
# Play 93, id: ostrovsky-snegurochka, ready: 65.96%
# Play 94, id: ostrovsky-svoi-ljudi, ready: 66.67%
# Play 95, id: ostrovsky-volki-i-ovtsy, ready: 67.38%
# Play 96, id: ozerov-dmitrij-donskoj, ready: 68.09%
# Play 97, id: pisarev-lukavin, ready: 68.79%
# Play 98, id: pisemskij-gorkaja-sudbina, ready: 69.50%
# Play 99, id: plavilshchikov-ermak-pokoritel-sibiri, ready: 70.21%
# Play 100, id: plavilshchikov-sgovor-kutejkina, ready: 70.92%
# Play 101, id: prutkov-blondy, ready: 71.63%
# Play 102, id: prutkov-chereposlov-sirech-frenolog, ready: 72.34%
# Play 103, id: prutkov-fantaziya, ready: 73.05%
# Play 104, id: prutkov-oprometchivyj-turka, ready: 73.76%
# Play 105, id: prutkov-spor-drevnih-grecheskih-filosofov, ready: 74.47%
# Play 106, id: prutkov-srodstvo-mirovyh-sil, ready: 75.18%
# Play 107, id: pushkin-boris-godunov, ready: 75.89%
# Play 108, id: pushkin-kamenniy-gost, ready: 76.60%
# Play 109, id: pushkin-mocart-i-saleri, ready: 77.30%
# Play 110, id: pushkin-pir-vo-vremja-chumy, ready: 78.01%
# Play 111, id: pushkin-rusalka, ready: 78.72%
# Play 112, id: pushkin-skupoj-rytsar, ready: 79.43%
# Play 113, id: pushkin-stseny-iz-rytsarskih-vremen, ready: 80.14%
# Play 114, id: saltykov-shchedrin-smert-pazuhina, ready: 80.85%
# Play 115, id: shakhovskoy-ne-lubo-ne-slushai, ready: 81.56%
# Play 116, id: shakhovskoy-pustodomy, ready: 82.27%
# Play 117, id: shakhovskoy-svoya-semya, ready: 82.98%
# Play 118, id: shakhovskoy-urok-koketkam, ready: 83.69%
# Play 119, id: sukhovo-kobylin-delo, ready: 84.40%
# Play 120, id: sukhovo-kobylin-smert-tarelkina, ready: 85.11%
# Play 121, id: sukhovo-kobylin-svadba-krechinskogo, ready: 85.82%
# Play 122, id: sumarokov-artistona, ready: 86.52%
# Play 123, id: sumarokov-dimitrij-samozvanets, ready: 87.23%
# Play 124, id: sumarokov-horev, ready: 87.94%
# Play 125, id: sumarokov-semira, ready: 88.65%
# Play 126, id: sumarokov-sinav-i-truvor, ready: 89.36%
# Play 127, id: tolstoy-smert-ioanna-groznogo, ready: 90.07%
# Play 128, id: tolstoy-tsar-boris, ready: 90.78%
# Play 129, id: tolstoy-tsar-fedor-ioannovich, ready: 91.49%
# Play 130, id: tolstoy-vlast-tmy, ready: 92.20%
# Play 131, id: tolstoy-zhivoy-trup, ready: 92.91%
# Play 132, id: tretyakov-protivogazy, ready: 93.62%
# Play 133, id: turgenev-gde-tonko-tam-i-rvetsja, ready: 94.33%
# Play 134, id: turgenev-holostjak, ready: 95.04%
# Play 135, id: turgenev-mesjats-v-derevne, ready: 95.74%
# Play 136, id: turgenev-nahlebnik, ready: 96.45%
# Play 137, id: turgenev-neostorozhnost, ready: 97.16%
# Play 138, id: turgenev-provintsialka, ready: 97.87%
# Play 139, id: turgenev-razgovor-na-bolshoj-doroge, ready: 98.58%
# Play 140, id: turgenev-vecher-v-sorrente, ready: 99.29%
# Play 141, id: turgenev-zavtrak-u-predvoditelja, ready: 100.00%

# %%
for key, value in additional_features.items():
    df[key] = value
df.head()
# Out:
#                name    genre  year  numOfSegments  numOfActs  numOfSpeakers  \
# 0     andreyev-mysl  tragedy  1914              6          3             15
# 1  andreyev-ne-ubiy  unknown  1913              6          5             23
# 2      babel-marija  unknown  1935              8          0             22
# 3       babel-zakat  unknown  1927              8          0             36
# 4  blok-balaganchik  unknown  1906              3          0             16
#
#    wikipediaLinkCount  directionsCount  directionsTokens  \
# 0                   0              233              2748
# 1                   0              341              4334
# 2                   0              137              1632
# 3                   0              293              3412
# 4                   0               38              1091
#
#    directionsTokensAverage  directionsLemmas  directionsLemmasAverage  \
# 0                11.793991              1976                 8.480687
# 1                12.709677              3131                 9.181818
# 2                11.912409              1141                 8.328467
# 3                11.645051              2474                 8.443686
# 4                28.710526               864                22.736842
#
#    directionsPOS  directionsPOSAverage
# 0           1976              8.480687
# 1           3131              9.181818
# 2           1141              8.328467
# 3           2474              8.443686
# 4            864             22.736842

# %% [markdown]
# Now, the CSV contains following data:
#
# * _genre_: tragedy / comedy / unknown
#
# * _name_: `play_id` to address the API
#
# * _year_: single year for each play, chosen between written, published and staged plays,
#
# * _numOfSegments_: number of the smallest segments (scenes) in the play,
#
# * _numOfActs_,
#
# * _numOfSpeakers_,
#
# * _wikipediaLinkCount_: how many Wikipedia articles have a link to this Wikidata item
#
# * _directionsCount_, _directionsTokens_, _directionsTokensAverage_, _directionsLemmas_, _directionsLemmasAverage_, _directionsPOS_, _directionsPOSAverage_ — from `additional_features`

# %%
df_path = os.path.join(datasets_folder, "metadata_with_directions.csv")

# %%
df.to_csv(df_path, sep=";", encoding="utf-8")
